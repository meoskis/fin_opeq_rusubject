# %%
import json

# %%
#               subjects_board - Субъекты Российской Федерации, граничащие с другими государствами
#        subjects_board_cities - Города-столицы субъектов Российской Федерации
# subjects_board_cities_coords - Координаты городов столиц


subjects_board = ['Республика Карелия',
                  'Калининградская область',
                  'Ленинградская область',
                  'Мурманская область',
                  'Псковская область',
                  'Белгородская область',
                  'Брянская область',
                  'Курская область',
                  'Смоленская область',
                  'Республика Калмыкия',
                  'Краснодарский край',
                  'Астраханская область',
                  'Волгоградская область',
                  'Республика Дагестан',
                  'Кабардино-Балкарская Республика',
                  'Карачаево-Черкесская Республика',
                  'Республика Ингушетия',
                  'Республика Северная Осетия-Алания',
                  'Чеченская республика',
                  'Оренбургская область',
                  'Самарская область',
                  'Саратовская область',
                  'Курганская область',
                  'Тюменская область',
                  'Челябинская область',
                  'Республика Алтай',
                  'Республика Тыва',
                  'Алтайский край',
                  'Новосибирская область',
                  'Омская область',
                  'Республика Бурятия',
                  'Забайкальский край',
                  'Приморский край',
                  'Хабаровский край',
                  'Амурская область',
                  'Чукотский автономный округ',
                  'Еврейская автономная область',
                  'Херсонская область',
                  'Запорожская область',
                  'Донецкая Народная Республика',
                  'Луганская Народная Республика'
                 ]

board_countries = [['Финляндия'],
                  ['Польша','Литва'],
                  ['Финляндия','Эстония'],
                  ['Норвегия','Финляндия'],
                  ['Белоруссия','Латвия','Эстония'],
                  ['Украина'],
                  ['Белоруссия','Украина'],
                  ['Украина'],
                  ['Белоруссия'],
                  ['Казахстан'],
                  ['Абхазия'],
                  ['Казахстан'],
                  ['Казахстан'],
                  ['Азербайджан','Грузия'],
                  ['Грузия'],
                  ['Абхазия','Грузия'],
                  ['Грузия'],
                  ['Грузия','Южная Осетия'],
                  ['Грузия'],
                  ['Казахстан'],
                  ['Казахстан'],
                  ['Казахстан'],
                  ['Казахстан'],
                  ['Казахстан'],
                  ['Казахстан'],
                  ['Казахстан','Китай','Монголия'],
                  ['Монголия'],
                  ['Казахстан'],
                  ['Казахстан'],
                  ['Казахстан'],
                  ['Монголия'],
                  ['Китай', 'Монголия'],
                  ['Китай','КНДР'],
                  ['Китай'],
                  ['Китай'],
                  ['США'],
                  ['Китай'],
                  ['Украина'],
                  ['Украина'],
                  ['Украина'],
                  ['Украина']]

subjects_board_cities = ['Петрозаводск',
                         'Калининград',
                         'Санкт-Петербург',
                         'Мурманск',
                         'Псков',
                         'Белгород',
                         'Брянск',
                         'Курск',
                         'Смоленск',
                         'Элиста',
                         'Краснодар',
                         'Астрахань',
                         'Волгоград',
                         'Махачкала',
                         'Нальчик',
                         'Черкесск',
                         'Магас',
                         'Владикавказ',
                         'Грозный',
                         'Оренбург',
                         'Самара',
                         'Саратов',
                         'Курган',
                         'Тюмень',
                         'Челябинск',
                         'Горно-Алтайск',
                         'Кызыл',
                         'Барнаул',
                         'Новосибирск',
                         'Омск',
                         'Улан-Удэ',
                         'Чита',
                         'Владивосток',
                         'Хабаровск',
                         'Благовещенск',
                         'Анадырь',
                         'Биробиджан',
                         'Херсон',
                         'Запорожье',
                         'Донецк',
                         'Луганск']

subjects_board_cities_coords = ['61,7849 с. ш., 34,3469 в. д.',
                                '54,7065 с. ш., 20,511 в. д.',
                                '59,9386 с. ш., 30,3141 в. д.',
                                '68,9792 с. ш., 33,0925 в. д.',
                                '57,8136 с. ш., 28,3496 в. д.',
                                '50,6107 с. ш., 36,5802 в. д.',
                                '53,2521 с. ш., 34,3717 в. д.',
                                '51,7373 с. ш., 36,1874 в. д.',
                                '54,7818 с. ш., 32,0401 в. д.',
                                '46,3078 с. ш., 44,2558 в. д.',
                                '45,0448 с. ш., 38,976 в. д.',
                                '46,3497 с. ш., 48,0408 в. д.',
                                '48,7194 с. ш., 44,5018 в. д.',
                                '42,9764 с. ш., 47,5024 в. д.',
                                '43,4981 с. ш., 43,6189 в. д.',
                                '44,2233 с. ш., 42,0578 в. д.',
                                '43,2226 с. ш., 44,7726 в. д.',
                                '43,0367 с. ш., 44,6678 в. д.',
                                '43,312 с. ш., 45,6889 в. д.',
                                '51,7727 с. ш., 55,0988 в. д.',
                                '53,2001 с. ш., 50,15 в. д.',
                                '51,5406 с. ш., 46,0086 в. д.',
                                '55,45 с. ш., 65,3333 в. д.',
                                '57,1522 с. ш., 65,5272 в. д.',
                                '55,154 с. ш., 61,4291 в. д.',
                                '51,9606 с. ш., 85,9189 в. д.',
                                '51,7147 с. ш., 94,4534 в. д.',
                                '53,3606 с. ш., 83,7636 в. д.',
                                '55,0415 с. ш., 82,9346 в. д.',
                                '54,9924 с. ш., 73,3686 в. д.',
                                '51,8272 с. ш., 107,606 в. д.',
                                '52,0317 с. ш., 113,501 в. д.',
                                '43,1056 с. ш., 131,874 в. д.',
                                '48,4827 с. ш., 135,084 в. д.',
                                '50,2796 с. ш., 127,54 в. д.',
                                '64,7342 с. ш., 177,51 в. д.',
                                '48,7928 с. ш., 132,924 в. д.',
                                '46,6558 с. ш., 32,6178 в. д.',
                                '47,8229 с. ш., 35,1903 в. д.',
                                '48,023 с. ш., 37,8022 в. д.',
                                '48,5671 с. ш., 39,3171 в. д.']

# %%
# Создание массива данных для записи в json
result_json_file = []
for data in range(len(subjects_board)):
    subject_dict = {}
    subject_dict['subjects_board'] = subjects_board[data]
    subject_dict['board_countries'] = board_countries[data]
    subject_dict['subjects_board_cities'] = subjects_board_cities[data]
    subject_dict['subjects_board_cities_coords'] = subjects_board_cities_coords[data]
    result_json_file.append(subject_dict)
result_json_file[:3]
# Out:
# [{'subjects_board': 'Республика Карелия',
#   'board_countries': ['Финляндия'],
#   'subjects_board_cities': 'Петрозаводск',
#   'subjects_board_cities_coords': '61,7849 с. ш., 34,3469 в. д.'},
#  {'subjects_board': 'Калининградская область',
#   'board_countries': ['Польша', 'Литва'],
#   'subjects_board_cities': 'Калининград',
#   'subjects_board_cities_coords': '54,7065 с. ш., 20,511 в. д.'},
#  {'subjects_board': 'Ленинградская область',
#   'board_countries': ['Финляндия', 'Эстония'],
#   'subjects_board_cities': 'Санкт-Петербург',
#   'subjects_board_cities_coords': '59,9386 с. ш., 30,3141 в. д.'}]

# %%
#все файлы были установлены в папку пользователя на диске C:
with open("rusubjects_data.json", "w") as outfile:
    json.dump(result_json_file, outfile)
